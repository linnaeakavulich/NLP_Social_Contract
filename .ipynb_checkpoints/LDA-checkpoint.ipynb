# %% [markdown]
# # Metadata
#
# ```
# Author: Linnaea Kavulich
# Contact: qpk4kp@virginia.edu
# Course: DS 5001 (Spring 2023)
# ```

# %% [markdown]
# <h1><center>The State of Natural Language Processing</center></h1>
# <h3><center>An exploration of the infamous Locke-Hobbes-Rousseau Debate Using NLP techniques</center></h3>

# %% [markdown]
# ***

# %% [markdown]
# <center>This notebook imports tables in F4 format to perform PCA.</center>

# %% [markdown]
# | Book_id | Title | Author |
# | :- | :- | :- |
# | 1 | The Social Contract | Jean-Jacques Rousseau
# | 2 | Leviathan | Thomas Hobbes
# | 3 | Second Treatise of Government | John Locke
# | 4 | Discourse on the Origin and Basis of Inequality Among Men | Jean-Jacques Rousseau
# | 5 | An Essay Concerning Humane Understanding, Vol. 1 | John Locke
# | 6 | An Essay Concerning Humane Understanding, Vol. 2 | John Locke

# %% [markdown]
# ## Import Packages

# %%
import numpy as np
import pandas as pd

import os
os.chdir('C:/Users/linna/Box/MSDS/DS5001/Final Project/Corpus/')

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA
import plotly_express as px

# %%
OHCO = ['book_id', 'chap_num', 'para_num']
PARA = OHCO[:3]
CHAP = OHCO[:2]
BOOK = OHCO[:1]

# %% [markdown]
# ***

# %% [markdown]
# ## Load CORPUS, convert to DOCS

# %%
CORPUS = pd.read_csv('CORPUS.csv')

# %%
CORPUS.head()
# Out:
#    book_id  chap_num  para_num  sent_num  token_num token_str term_str pos
# 0        1         1         0         0          0   SUBJECT  subject  NN
# 1        1         1         0         0          1        OF       of  IN
# 2        1         1         0         0          2       THE      the  DT
# 3        1         1         0         0          3     FIRST    first  JJ
# 4        1         1         0         0          4      BOOK     book  NN

# %%
CORPUS['term_str'] = CORPUS['term_str'].astype(str)

# %%
CORPUS.dtypes
# Out:
# book_id       int64
# chap_num      int64
# para_num      int64
# sent_num      int64
# token_num     int64
# token_str    object
# term_str     object
# pos          object
# dtype: object

# %%
DOCS = CORPUS[CORPUS.pos.str.match(r'^NNS?$')]\
    .groupby(CHAP).term_str\
    .apply(lambda x: ' '.join(x))\
    .to_frame()\
    .rename(columns={'term_str':'doc_str'})

# %%
DOCS
# Out:
#                                                             doc_str
# book_id chap_num
# 1       1         subject book man chains master others slave ch...
#         2         societies one family children father preservat...
#         3         right strongest master strength right obedienc...
#         4         slavery man authority force right conventions ...
#         5         convention i friends despotism difference mult...
# ...                                                             ...
# 6       27        assent grounds probability grounds probability...
#         28        significations word reason word reason languag...
#         29        faith reason provinces boundaries necessity ig...
#         31        assent error causes error men contrary probabi...
#         32        division sciences science sorts compass nature...
#
# [183 rows x 1 columns]

# %%
count_engine = CountVectorizer(max_features=4000, ngram_range=[1,2], stop_words='english')
count_model = count_engine.fit_transform(DOCS.doc_str)
TERMS = count_engine.get_feature_names_out()

# %%
VOCAB = pd.DataFrame(index=TERMS)
VOCAB.index.name = 'term_str'

# %%
DTM = pd.DataFrame(count_model.toarray(), index=DOCS.index, columns=TERMS)

# %%
VOCAB['doc_count'] = DTM.astype('bool').astype('int').sum()
DOCS['term_count'] = DTM.sum(1)

# %%
DOCS.term_count.describe()
# Out:
# count      183.000000
# mean       772.032787
# std       1082.676597
# min         23.000000
# 25%        188.000000
# 50%        523.000000
# 75%       1020.000000
# max      11182.000000
# Name: term_count, dtype: float64

# %%
lda_engine = LDA(n_components=40, max_iter=20, learning_offset=50., random_state=0)

# %%
TNAMES = [f"T{str(x).zfill(len(str(40)))}" for x in range(40)]

# %%
lda_model = lda_engine.fit_transform(count_model)

# %%
THETA = pd.DataFrame(lda_model, index=DOCS.index)
THETA.columns.name = 'topic_id'
THETA.columns = TNAMES

# %%
THETA.sample(20).style.background_gradient(cmap='GnBu', axis=None)
# Out:
# <style type="text/css">
# #T_7024e_row0_col0, #T_7024e_row0_col1, #T_7024e_row0_col2, #T_7024e_row0_col3, #T_7024e_row0_col4, #T_7024e_row0_col5, #T_7024e_row0_col6, #T_7024e_row0_col7, #T_7024e_row0_col8, #T_7024e_row0_col9, #T_7024e_row0_col10, #T_7024e_row0_col11, #T_7024e_row0_col12, #T_7024e_row0_col13, #T_7024e_row0_col14, #T_7024e_row0_col15, #T_7024e_row0_col16, #T_7024e_row0_col17, #T_7024e_row0_col18, #T_7024e_row0_col19, #T_7024e_row0_col20, #T_7024e_row0_col21, #T_7024e_row0_col22, #T_7024e_row0_col23, #T_7024e_row0_col24, #T_7024e_row0_col25, #T_7024e_row0_col26, #T_7024e_row0_col27, #T_7024e_row0_col29, #T_7024e_row0_col31, #T_7024e_row0_col32, #T_7024e_row0_col33, #T_7024e_row0_col34, #T_7024e_row0_col35, #T_7024e_row0_col36, #T_7024e_row0_col39, #T_7024e_row1_col0, #T_7024e_row1_col1, #T_7024e_row1_col2, #T_7024e_row1_col3, #T_7024e_row1_col4, #T_7024e_row1_col5, #T_7024e_row1_col6, #T_7024e_row1_col7, #T_7024e_row1_col8, #T_7024e_row1_col9, #T_7024e_row1_col10, #T_7024e_row1_col11, #T_7024e_row1_col12, #T_7024e_row1_col13, #T_7024e_row1_col14, #T_7024e_row1_col15, #T_7024e_row1_col16, #T_7024e_row1_col17, #T_7024e_row1_col18, #T_7024e_row1_col19, #T_7024e_row1_col20, #T_7024e_row1_col21, #T_7024e_row1_col22, #T_7024e_row1_col23, #T_7024e_row1_col24, #T_7024e_row1_col25, #T_7024e_row1_col26, #T_7024e_row1_col27, #T_7024e_row1_col28, #T_7024e_row1_col29, #T_7024e_row1_col31, #T_7024e_row1_col32, #T_7024e_row1_col33, #T_7024e_row1_col34, #T_7024e_row1_col35, #T_7024e_row1_col36, #T_7024e_row1_col37, #T_7024e_row1_col38, #T_7024e_row1_col39, #T_7024e_row2_col0, #T_7024e_row2_col1, #T_7024e_row2_col2, #T_7024e_row2_col3, #T_7024e_row2_col4, #T_7024e_row2_col5, #T_7024e_row2_col6, #T_7024e_row2_col7, #T_7024e_row2_col8, #T_7024e_row2_col10, #T_7024e_row2_col13, #T_7024e_row2_col14, #T_7024e_row2_col15, #T_7024e_row2_col16, #T_7024e_row2_col17, #T_7024e_row2_col18, #T_7024e_row2_col19, #T_7024e_row2_col20, #T_7024e_row2_col21, #T_7024e_row2_col22, #T_7024e_row2_col23, #T_7024e_row2_col24, #T_7024e_row2_col25, #T_7024e_row2_col26, #T_7024e_row2_col27, #T_7024e_row2_col28, #T_7024e_row2_col29, #T_7024e_row2_col31, #T_7024e_row2_col32, #T_7024e_row2_col33, #T_7024e_row2_col34, #T_7024e_row2_col35, #T_7024e_row2_col36, #T_7024e_row2_col37, #T_7024e_row2_col38, #T_7024e_row2_col39, #T_7024e_row3_col0, #T_7024e_row3_col1, #T_7024e_row3_col2, #T_7024e_row3_col4, #T_7024e_row3_col5, #T_7024e_row3_col6, #T_7024e_row3_col7, #T_7024e_row3_col8, #T_7024e_row3_col9, #T_7024e_row3_col10, #T_7024e_row3_col11, #T_7024e_row3_col12, #T_7024e_row3_col13, #T_7024e_row3_col14, #T_7024e_row3_col15, #T_7024e_row3_col16, #T_7024e_row3_col17, #T_7024e_row3_col18, #T_7024e_row3_col19, #T_7024e_row3_col20, #T_7024e_row3_col22, #T_7024e_row3_col23, #T_7024e_row3_col24, #T_7024e_row3_col25, #T_7024e_row3_col27, #T_7024e_row3_col28, #T_7024e_row3_col29, #T_7024e_row3_col30, #T_7024e_row3_col31, #T_7024e_row3_col32, #T_7024e_row3_col33, #T_7024e_row3_col35, #T_7024e_row3_col36, #T_7024e_row3_col37, #T_7024e_row3_col38, #T_7024e_row3_col39, #T_7024e_row4_col0, #T_7024e_row4_col1, #T_7024e_row4_col2, #T_7024e_row4_col4, #T_7024e_row4_col5, #T_7024e_row4_col6, #T_7024e_row4_col7, #T_7024e_row4_col8, #T_7024e_row4_col9, #T_7024e_row4_col10, #T_7024e_row4_col11, #T_7024e_row4_col12, #T_7024e_row4_col13, #T_7024e_row4_col14, #T_7024e_row4_col16, #T_7024e_row4_col17, #T_7024e_row4_col18, #T_7024e_row4_col19, #T_7024e_row4_col20, #T_7024e_row4_col21, #T_7024e_row4_col22, #T_7024e_row4_col23, #T_7024e_row4_col24, #T_7024e_row4_col25, #T_7024e_row4_col27, #T_7024e_row4_col28, #T_7024e_row4_col29, #T_7024e_row4_col30, #T_7024e_row4_col31, #T_7024e_row4_col32, #T_7024e_row4_col33, #T_7024e_row4_col35, #T_7024e_row4_col36, #T_7024e_row4_col37, #T_7024e_row4_col39, #T_7024e_row5_col0, #T_7024e_row5_col1, #T_7024e_row5_col2, #T_7024e_row5_col3, #T_7024e_row5_col5, #T_7024e_row5_col6, #T_7024e_row5_col7, #T_7024e_row5_col8, #T_7024e_row5_col9, #T_7024e_row5_col10, #T_7024e_row5_col11, #T_ ...

# %%
PHI = pd.DataFrame(lda_engine.components_, columns=TERMS, index=TNAMES)
PHI.index.name = 'topic_id'
PHI.columns.name  = 'term_str'

# %%
PHI.T.sample(20).style.background_gradient(cmap='GnBu', axis=None)
# Out:
# <style type="text/css">
# #T_d1b96_row0_col0, #T_d1b96_row0_col1, #T_d1b96_row0_col2, #T_d1b96_row0_col3, #T_d1b96_row0_col4, #T_d1b96_row0_col5, #T_d1b96_row0_col6, #T_d1b96_row0_col7, #T_d1b96_row0_col8, #T_d1b96_row0_col9, #T_d1b96_row0_col10, #T_d1b96_row0_col11, #T_d1b96_row0_col12, #T_d1b96_row0_col13, #T_d1b96_row0_col14, #T_d1b96_row0_col15, #T_d1b96_row0_col16, #T_d1b96_row0_col17, #T_d1b96_row0_col18, #T_d1b96_row0_col19, #T_d1b96_row0_col20, #T_d1b96_row0_col21, #T_d1b96_row0_col22, #T_d1b96_row0_col23, #T_d1b96_row0_col24, #T_d1b96_row0_col25, #T_d1b96_row0_col27, #T_d1b96_row0_col28, #T_d1b96_row0_col29, #T_d1b96_row0_col30, #T_d1b96_row0_col31, #T_d1b96_row0_col32, #T_d1b96_row0_col33, #T_d1b96_row0_col34, #T_d1b96_row0_col35, #T_d1b96_row0_col36, #T_d1b96_row0_col37, #T_d1b96_row0_col38, #T_d1b96_row0_col39, #T_d1b96_row1_col0, #T_d1b96_row1_col1, #T_d1b96_row1_col2, #T_d1b96_row1_col3, #T_d1b96_row1_col4, #T_d1b96_row1_col5, #T_d1b96_row1_col6, #T_d1b96_row1_col7, #T_d1b96_row1_col8, #T_d1b96_row1_col9, #T_d1b96_row1_col10, #T_d1b96_row1_col11, #T_d1b96_row1_col12, #T_d1b96_row1_col13, #T_d1b96_row1_col14, #T_d1b96_row1_col15, #T_d1b96_row1_col16, #T_d1b96_row1_col17, #T_d1b96_row1_col18, #T_d1b96_row1_col19, #T_d1b96_row1_col20, #T_d1b96_row1_col21, #T_d1b96_row1_col22, #T_d1b96_row1_col23, #T_d1b96_row1_col24, #T_d1b96_row1_col25, #T_d1b96_row1_col26, #T_d1b96_row1_col27, #T_d1b96_row1_col28, #T_d1b96_row1_col29, #T_d1b96_row1_col30, #T_d1b96_row1_col31, #T_d1b96_row1_col32, #T_d1b96_row1_col33, #T_d1b96_row1_col34, #T_d1b96_row1_col35, #T_d1b96_row1_col36, #T_d1b96_row1_col37, #T_d1b96_row1_col38, #T_d1b96_row1_col39, #T_d1b96_row2_col0, #T_d1b96_row2_col1, #T_d1b96_row2_col2, #T_d1b96_row2_col3, #T_d1b96_row2_col4, #T_d1b96_row2_col5, #T_d1b96_row2_col6, #T_d1b96_row2_col8, #T_d1b96_row2_col9, #T_d1b96_row2_col10, #T_d1b96_row2_col11, #T_d1b96_row2_col12, #T_d1b96_row2_col13, #T_d1b96_row2_col14, #T_d1b96_row2_col15, #T_d1b96_row2_col16, #T_d1b96_row2_col17, #T_d1b96_row2_col18, #T_d1b96_row2_col19, #T_d1b96_row2_col20, #T_d1b96_row2_col21, #T_d1b96_row2_col22, #T_d1b96_row2_col23, #T_d1b96_row2_col24, #T_d1b96_row2_col25, #T_d1b96_row2_col26, #T_d1b96_row2_col28, #T_d1b96_row2_col29, #T_d1b96_row2_col30, #T_d1b96_row2_col32, #T_d1b96_row2_col33, #T_d1b96_row2_col34, #T_d1b96_row2_col35, #T_d1b96_row2_col36, #T_d1b96_row2_col37, #T_d1b96_row2_col38, #T_d1b96_row2_col39, #T_d1b96_row3_col0, #T_d1b96_row3_col1, #T_d1b96_row3_col2, #T_d1b96_row3_col3, #T_d1b96_row3_col4, #T_d1b96_row3_col5, #T_d1b96_row3_col6, #T_d1b96_row3_col7, #T_d1b96_row3_col8, #T_d1b96_row3_col9, #T_d1b96_row3_col10, #T_d1b96_row3_col11, #T_d1b96_row3_col12, #T_d1b96_row3_col13, #T_d1b96_row3_col14, #T_d1b96_row3_col15, #T_d1b96_row3_col16, #T_d1b96_row3_col17, #T_d1b96_row3_col18, #T_d1b96_row3_col19, #T_d1b96_row3_col20, #T_d1b96_row3_col21, #T_d1b96_row3_col22, #T_d1b96_row3_col23, #T_d1b96_row3_col24, #T_d1b96_row3_col26, #T_d1b96_row3_col27, #T_d1b96_row3_col28, #T_d1b96_row3_col29, #T_d1b96_row3_col30, #T_d1b96_row3_col31, #T_d1b96_row3_col32, #T_d1b96_row3_col33, #T_d1b96_row3_col34, #T_d1b96_row3_col35, #T_d1b96_row3_col36, #T_d1b96_row3_col37, #T_d1b96_row3_col38, #T_d1b96_row3_col39, #T_d1b96_row4_col0, #T_d1b96_row4_col1, #T_d1b96_row4_col2, #T_d1b96_row4_col3, #T_d1b96_row4_col4, #T_d1b96_row4_col5, #T_d1b96_row4_col6, #T_d1b96_row4_col7, #T_d1b96_row4_col8, #T_d1b96_row4_col9, #T_d1b96_row4_col10, #T_d1b96_row4_col11, #T_d1b96_row4_col12, #T_d1b96_row4_col13, #T_d1b96_row4_col14, #T_d1b96_row4_col15, #T_d1b96_row4_col16, #T_d1b96_row4_col18, #T_d1b96_row4_col19, #T_d1b96_row4_col20, #T_d1b96_row4_col21, #T_d1b96_row4_col22, #T_d1b96_row4_col23, #T_d1b96_row4_col24, #T_d1b96_row4_col25, #T_d1b96_row4_col26, #T_d1b96_row4_col27, #T_d1b96_row4_col28, #T_d1b96_row4_col29, #T_d1b96_row4_col30, #T_d1b96_row4_col31, #T_d1b96_row4_col32, #T_d1b96_row4_col33, #T_d1b96_row4_col34, #T_d1b96_row4_col35, #T_d1b96_row4_col36, #T_d1b96_row4_col37, #T_d1b96_row4_col ...

# %%
TOPICS = PHI.stack().to_frame('topic_weight').groupby('topic_id')\
    .apply(lambda x: x.sort_values('topic_weight', ascending=False)\
        .head(9).reset_index().drop('topic_id', axis=1)['term_str'])

# %%
TOPICS
# Out:
# term_str             0              1                 2  \
# topic_id
# T00              aaron         pieces  person soveraign
# T01              power            men           worship
# T02              aaron         pieces  person soveraign
# T03              ideas           idea              mind
# T04              words          ideas             names
# T05                god         spirit             sense
# T06              ideas       relation            things
# T07                law            man            nature
# T08           property           land               use
# T09           duration           idea             ideas
# T10              modes          ideas             names
# T11                men            man             state
# T12               body          space              idea
# T13       consequences   commonwealth            bodies
# T14            species          ideas           essence
# T15          knowledge          ideas         agreement
# T16              power         action          pleasure
# T17                men     principles               god
# T18         philosophy            men               man
# T19              aaron         pieces  person soveraign
# T20           abstract  abstract idea  difference ideas
# T21                man  consciousness          identity
# T22         perception          ideas              mind
# T23          soveraign   commonwealth          assembly
# T24              aaron         pieces  person soveraign
# T25                god           word          prophets
# T26              ideas      qualities            motion
# T27                men          power               man
# T28              power        society             state
# T29              aaron         pieces  person soveraign
# T30         government         people             state
# T31           children         father             power
# T32                god       religion             moses
# T33                god         christ            church
# T34             reason            use              mind
# T35          knowledge          ideas      propositions
# T36             people      interests      associations
# T37              right            man            nature
# T38                man         matter            things
# T39             number          names              idea
#
# term_str                       3              4             5  \
# topic_id
# T00                      persons           peru         peter
# T01                          man            god  commonwealth
# T02                      persons           peru         peter
# T03                       things     substances         power
# T04                          use  signification           men
# T05                          men          place          word
# T06                    relations           idea           men
# T07                          men          lawes         crime
# T08                       labour          right           men
# T09                        space           time        motion
# T10                         mind    ideas names       actions
# T11                       nature           laws       society
# T12                        parts         motion     extension
# T13                    soveraign        science           man
# T14                       things           idea         names
# T15       agreement disagreement   disagreement          mind
# T16                         mind           pain           man
# T17                        minds         innate         truth
# T18                         body            law         cause
# T19                      persons           peru         peter
# T20                thing essence    rationality     signifies
# T21                       person      substance          body
# T22                    sensation           idea       animals
# T23                    authority    soveraignty        people
# T24                      persons           peru         peter
# T25                      prophet            man          time
# T26                       senses           mind        bodies
# T27                         time         things         right
# T28                         laws         people           men
# T29                      persons           peru         peter
# T30                         body           laws         power
# T31                          man            law       parents
# T32                         gods         people      kingdome
# T33                          man          power      kingdome
# T34                        ideas   propositions           men
# T35                    certainty           idea         truth
# T36                  differences      agreement       society
# T37                      liberty       covenant           men
# T38                        thing            men     knowledge
# T39                      numbers          ideas     confusion
#
# term_str                   6              7                  8
# topic_id
# T00                phantasme     phantasmes        philosopher
# T01                    image          lawes            actions
# T02                phantasme     phantasmes        philosopher
# T03                    minds          modes              parts
# T04                     word           idea             things
# T05                    words        spirits             vision
# T06                    thing            man            actions
# T07             commonwealth     law nature             reason
# T08                      man           life             nature
# T09                 infinity           mind         succession
# T10                   notice            men        modes ideas
# T11                     life           time             people
# T12                   bodies          place          substance
# T13                  letters   distribution               body
# T14                 essences     substances                man
# T15       disagreement ideas  demonstration         perception
# T16                happiness         desire            liberty
# T17                      man      knowledge          principle
# T18                    place          names            schools
# T19                phantasme     phantasmes        philosopher
# T20              essence man    grammarians            chiefly
# T21                     soul        actions               self
# T22                   notice            man               cube
# T23                   person       subjects              power
# T24                phantasme     phantasmes        philosopher
# T25                    books       miracles              words
# T26                      man           soul            objects
# T27                   reason         nature             people
# T28                   nature          force       state nature
# T29                phantasme     phantasmes        philosopher
# T30                authority      sovereign             prince
# T31                   reason         nature         government
# T32                   church        priests          authority
# T33                      men        saviour           apostles
# T34                knowledge     principles             maxims
# T35                existence         things        proposition
# T36                      man      societies                act
# T37                      war            law               life
# T38                 thoughts    probability             reason
# T39                 millions       addition  millions millions

# %%
TOPICS['label'] = TOPICS.apply(lambda x: x.name + ' ' + ', '.join(x[:9]), 1)

# %%
print(TOPICS.label.values)
# Out:
# ['T00 aaron, pieces, person soveraign, persons, peru, peter, phantasme, phantasmes, philosopher'
#  'T01 power, men, worship, man, god, commonwealth, image, lawes, actions'
#  'T02 aaron, pieces, person soveraign, persons, peru, peter, phantasme, phantasmes, philosopher'
#  'T03 ideas, idea, mind, things, substances, power, minds, modes, parts'
#  'T04 words, ideas, names, use, signification, men, word, idea, things'
#  'T05 god, spirit, sense, men, place, word, words, spirits, vision'
#  'T06 ideas, relation, things, relations, idea, men, thing, man, actions'
#  'T07 law, man, nature, men, lawes, crime, commonwealth, law nature, reason'
#  'T08 property, land, use, labour, right, men, man, life, nature'
#  'T09 duration, idea, ideas, space, time, motion, infinity, mind, succession'
#  'T10 modes, ideas, names, mind, ideas names, actions, notice, men, modes ideas'
#  'T11 men, man, state, nature, laws, society, life, time, people'
#  'T12 body, space, idea, parts, motion, extension, bodies, place, substance'
#  'T13 consequences, commonwealth, bodies, soveraign, science, man, letters, distribution, body'
#  'T14 species, ideas, essence, things, idea, names, essences, substances, man'
#  'T15 knowledge, ideas, agreement, agreement disagreement, disagreement, mind, disagreement ideas, demonstration, perception'
#  'T16 power, action, pleasure, mind, pain, man, happiness, desire, liberty'
#  'T17 men, principles, god, minds, innate, truth, man, knowledge, principle'
#  'T18 philosophy, men, man, body, law, cause, place, names, schools'
#  'T19 aaron, pieces, person soveraign, persons, peru, peter, phantasme, phantasmes, philosopher'
#  'T20 abstract, abstract idea, difference ideas, thing essence, rationality, signifies, essence man, grammarians, chiefly'
#  'T21 man, consciousness, identity, person, substance, body, soul, actions, self'
#  'T22 perception, ideas, mind, sensation, idea, animals, notice, man, cube'
#  'T23 soveraign, commonwealth, assembly, authority, soveraignty, people, person, subjects, power'
#  'T24 aaron, pieces, person soveraign, persons, peru, peter, phantasme, phantasmes, philosopher'
#  'T25 god, word, prophets, prophet, man, time, books, miracles, words'
#  'T26 ideas, qualities, motion, senses, mind, bodies, man, soul, objects'
#  'T27 men, power, man, time, things, right, reason, nature, people'
#  'T28 power, society, state, laws, people, men, nature, force, state nature'
#  'T29 aaron, pieces, person soveraign, persons, peru, peter, phantasme, phantasmes, philosopher'
#  'T30 government, people, state, body, laws, power, authority, sovereign, prince'
#  'T31 children, father, power, man, law, parents, reason, nature, government'
#  'T32 god, religion, moses, gods, people, kingdome, church, priests, authority'
#  'T33 god, christ, church, man, power, kingdome, men, saviour, apostles'
#  'T34 reason, use, mind, ideas, propositions, men, knowledge, principles, maxims'
#  'T35 knowledge, ideas, propositions, certainty, idea, truth, existence, things, proposition'
#  'T36 people, interests, associations, differences, agreement, society, man, societies, act'
#  'T37 right, man, nature, liberty, covenant, men, war, law, life'
#  'T38 man, matter, things, thing, men, knowledge, thoughts, probability, reason'
#  'T39 number, names, idea, numbers, ideas, confusion, millions, addition, millions millions']

# %%
TOPICS['doc_weight_sum'] = THETA.sum()
TOPICS['term_freq'] = PHI.sum(1) / PHI.sum(1).sum()

# %%
TOPICS.sort_values('doc_weight_sum', ascending=True).plot.barh(y='doc_weight_sum', x='label', figsize=(4, 16));

# %%
TOPICS.sort_values('term_freq', ascending=True).plot.barh(y='term_freq', x='label', figsize=(4, 16));

# %% [markdown]
# ## Now let's look at the differences between Hobbes, Locke and Rousseau

# %%
LIB = pd.read_csv('LIB.csv')

# %%
LIB = LIB.drop(columns='Unnamed: 0')

# %%
LIB
# Out:
#    book_id                source_file_path  \
# 0        1    social_contract_rousseau.txt
# 1        2            hobbes_leviathan.txt
# 2        3                locke_second.txt
# 3        4         rousseau_inequality.txt
# 4        5  humane_understanding_locke.txt
# 5        6   humane_understanding_vol2.txt
#
#                                  chap_regex  \
# 0        \s*(chapter)\s+(?=([IVX]+))(\s|$)
# 1                 \s*CHAPTER\s+[IVXLCDM]+\.
# 2              \s*CHAPTER+\.\s+[IVXLCDM]+\.
# 3  \s*(DISCOURSE FIRST PART|SECOND PART)\s*
# 4                \s*CHAPTER+\s+[IVXLCDM]+\.
# 5                \s*CHAPTER+\s+[IVXLCDM]+\.
#
#                                                title                 author  \
# 0                                The Social Contract  Jean-Jacques Rousseau
# 1                                          Leviathan          Thomas Hobbes
# 2                  The Second Treatise of Government             John Locke
# 3  A Discourse Upon The Origin And The Foundation...  Jean-Jacques Rousseau
# 4           An Essay Concerning Humane Understanding             John Locke
# 5  An Essay Concerning Humane Understanding, Volu...             John Locke
#
#    book_len  n_chaps
# 0    111749       48
# 1    224684       46
# 2     58125       19
# 3     26001        2
# 4    150692       37
# 5    130868       32

# %%
LIB['author_key'] = LIB.author.str.split(' ').str[1].str.lower()

# %%
LIB
# Out:
#    book_id                source_file_path  \
# 0        1    social_contract_rousseau.txt
# 1        2            hobbes_leviathan.txt
# 2        3                locke_second.txt
# 3        4         rousseau_inequality.txt
# 4        5  humane_understanding_locke.txt
# 5        6   humane_understanding_vol2.txt
#
#                                  chap_regex  \
# 0        \s*(chapter)\s+(?=([IVX]+))(\s|$)
# 1                 \s*CHAPTER\s+[IVXLCDM]+\.
# 2              \s*CHAPTER+\.\s+[IVXLCDM]+\.
# 3  \s*(DISCOURSE FIRST PART|SECOND PART)\s*
# 4                \s*CHAPTER+\s+[IVXLCDM]+\.
# 5                \s*CHAPTER+\s+[IVXLCDM]+\.
#
#                                                title                 author  \
# 0                                The Social Contract  Jean-Jacques Rousseau
# 1                                          Leviathan          Thomas Hobbes
# 2                  The Second Treatise of Government             John Locke
# 3  A Discourse Upon The Origin And The Foundation...  Jean-Jacques Rousseau
# 4           An Essay Concerning Humane Understanding             John Locke
# 5  An Essay Concerning Humane Understanding, Volu...             John Locke
#
#    book_len  n_chaps author_key
# 0    111749       48   rousseau
# 1    224684       46     hobbes
# 2     58125       19      locke
# 3     26001        2   rousseau
# 4    150692       37      locke
# 5    130868       32      locke

# %%
AUTHORS = sorted(LIB.author_key.value_counts().index.to_list())

# %%
TOPICS[AUTHORS] = THETA.join(LIB, on='book_id').groupby('author_key')[TNAMES].mean().T

# %%
TOPICS
# Out:
# term_str             0              1                 2  \
# topic_id
# T00              aaron         pieces  person soveraign
# T01              power            men           worship
# T02              aaron         pieces  person soveraign
# T03              ideas           idea              mind
# T04              words          ideas             names
# T05                god         spirit             sense
# T06              ideas       relation            things
# T07                law            man            nature
# T08           property           land               use
# T09           duration           idea             ideas
# T10              modes          ideas             names
# T11                men            man             state
# T12               body          space              idea
# T13       consequences   commonwealth            bodies
# T14            species          ideas           essence
# T15          knowledge          ideas         agreement
# T16              power         action          pleasure
# T17                men     principles               god
# T18         philosophy            men               man
# T19              aaron         pieces  person soveraign
# T20           abstract  abstract idea  difference ideas
# T21                man  consciousness          identity
# T22         perception          ideas              mind
# T23          soveraign   commonwealth          assembly
# T24              aaron         pieces  person soveraign
# T25                god           word          prophets
# T26              ideas      qualities            motion
# T27                men          power               man
# T28              power        society             state
# T29              aaron         pieces  person soveraign
# T30         government         people             state
# T31           children         father             power
# T32                god       religion             moses
# T33                god         christ            church
# T34             reason            use              mind
# T35          knowledge          ideas      propositions
# T36             people      interests      associations
# T37              right            man            nature
# T38                man         matter            things
# T39             number          names              idea
#
# term_str                       3              4             5  \
# topic_id
# T00                      persons           peru         peter
# T01                          man            god  commonwealth
# T02                      persons           peru         peter
# T03                       things     substances         power
# T04                          use  signification           men
# T05                          men          place          word
# T06                    relations           idea           men
# T07                          men          lawes         crime
# T08                       labour          right           men
# T09                        space           time        motion
# T10                         mind    ideas names       actions
# T11                       nature           laws       society
# T12                        parts         motion     extension
# T13                    soveraign        science           man
# T14                       things           idea         names
# T15       agreement disagreement   disagreement          mind
# T16                         mind           pain           man
# T17                        minds         innate         truth
# T18                         body            law         cause
# T19                      persons           peru         peter
# T20                thing essence    rationality     signifies
# T21                       person      substance          body
# T22                    sensation           idea       animals
# T23                    authority    soveraignty        people
# T24                      persons           peru         peter
# T25                      prophet            man          time
# T26                       senses           mind        bodies
# T27                         time         things         right
# T28                         laws         people           men
# T29                      persons           peru         peter
# T30                         body           laws         power
# T31                          man            law       parents
# T32                         gods         people      kingdome
# T33                          man          power      kingdome
# T34                        ideas   propositions           men
# T35                    certainty           idea         truth
# T36                  differences      agreement       society
# T37                      liberty       covenant           men
# T38                        thing            men     knowledge
# T39                      numbers          ideas     confusion
#
# term_str                   6              7                  8  \
# topic_id
# T00                phantasme     phantasmes        philosopher
# T01                    image          lawes            actions
# T02                phantasme     phantasmes        philosopher
# T03                    minds          modes              parts
# T04                     word           idea             things
# T05                    words        spirits             vision
# T06                    thing            man            actions
# T07             commonwealth     law nature             reason
# T08                      man           life             nature
# T09                 infinity           mind         succession
# T10                   notice            men        modes ideas
# T11                     life           time             people
# T12                   bodies          place          substance
# T13                  letters   distribution               body
# T14                 essences     substances                man
# T15       disagreement ideas  demonstration         perception
# T16                happiness         desire            liberty
# T17                      man      knowledge          principle
# T18                    place          names            schools
# T19                phantasme     phantasmes        philosopher
# T20              essence man    grammarians            chiefly
# T21                     soul        actions               self
# T22                   notice            man               cube
# T23                   person       subjects              power
# T24                phantasme     phantasmes        philosopher
# T25                    books       miracles              words
# T26                      man           soul            objects
# T27                   reason         nature             people
# T28                   nature          force       state nature
# T29                phantasme     phantasmes        philosopher
# T30                authority      sovereign             prince
# T31                   reason         nature         government
# T32                   church        priests          authority
# T33                      men        saviour           apostles
# T34                knowledge     principles             maxims
# T35                existence         things        proposition
# T36                      man      societies                act
# T37                      war            law               life
# T38                 thoughts    probability             reason
# T39                 millions       addition  millions millions
#
# term_str                                              label  doc_weight_sum  \
# topic_id
# T00       T00 aaron, pieces, person soveraign, persons, ...        0.018516
# T01       T01 power, men, worship, man, god, commonwealt...        3.357761
# T02       T02 aaron, pieces, person soveraign, persons, ...        0.018516
# T03       T03 ideas, idea, mind, things, substances, pow...       11.432458
# T04       T04 words, ideas, names, use, signification, m...        8.726934
# T05       T05 god, spirit, sense, men, place, word, word...        2.464164
# T06       T06 ideas, relation, things, relations, idea, ...        3.226677
# T07       T07 law, man, nature, men, lawes, crime, commo...        5.498739
# T08       T08 property, land, use, labour, right, men, m...        2.077141
# T09       T09 duration, idea, ideas, space, time, motion...        3.135642
# T10       T10 modes, ideas, names, mind, ideas names, ac...        1.478424
# T11       T11 men, man, state, nature, laws, society, li...       11.208434
# T12       T12 body, space, idea, parts, motion, extensio...        2.515309
# T13       T13 consequences, commonwealth, bodies, sovera...        2.374389
# T14       T14 species, ideas, essence, things, idea, nam...        4.427302
# T15       T15 knowledge, ideas, agreement, agreement dis...        4.000389
# T16       T16 power, action, pleasure, mind, pain, man, ...        3.906657
# T17       T17 men, principles, god, minds, innate, truth...        2.152975
# T18       T18 philosophy, men, man, body, law, cause, pl...        1.361390
# T19       T19 aaron, pieces, person soveraign, persons, ...        0.018516
# T20       T20 abstract, abstract idea, difference ideas,...        0.102190
# T21       T21 man, consciousness, identity, person, subs...        1.171659
# T22       T22 perception, ideas, mind, sensation, idea, ...        1.089321
# T23       T23 soveraign, commonwealth, assembly, authori...        3.083517
# T24       T24 aaron, pieces, person soveraign, persons, ...        0.018516
# T25       T25 god, word, prophets, prophet, man, time, b...        3.539895
# T26       T26 ideas, qualities, motion, senses, mind, bo...        7.616462
# T27       T27 men, power, man, time, things, right, reas...        9.695997
# T28       T28 power, society, state, laws, people, men, ...       11.052398
# T29       T29 aaron, pieces, person soveraign, persons, ...        0.018516
# T30       T30 government, people, state, body, laws, pow...       31.606534
# T31       T31 children, father, power, man, law, parents...        3.549218
# T32       T32 god, religion, moses, gods, people, kingdo...        1.654757
# T33       T33 god, christ, church, man, power, kingdome,...        6.160676
# T34       T34 reason, use, mind, ideas, propositions, me...        4.239986
# T35       T35 knowledge, ideas, propositions, certainty,...        5.325928
# T36       T36 people, interests, associations, differenc...        2.197485
# T37       T37 right, man, nature, liberty, covenant, men...        6.979989
# T38       T38 man, matter, things, thing, men, knowledge...        9.266305
# T39       T39 number, names, idea, numbers, ideas, confu...        1.230322
#
# term_str  term_freq    hobbes     locke  rousseau
# topic_id
# T00        0.000688  0.000213  0.000057  0.000087
# T01        0.021446  0.000213  0.038731  0.000087
# T02        0.000688  0.000213  0.000057  0.000087
# T03        0.048360  0.001537  0.105662  0.000087
# T04        0.050943  0.000213  0.015066  0.002467
# T05        0.018739  0.003482  0.026983  0.000087
# T06        0.017073  0.002381  0.026306  0.001203
# T07        0.043569  0.019882  0.047236  0.027523
# T08        0.010981  0.015502  0.001588  0.062867
# T09        0.026383  0.001462  0.036024  0.000087
# T10        0.004108  0.000213  0.015531  0.000087
# T11        0.106076  0.182510  0.024716  0.005894
# T12        0.017336  0.001672  0.026006  0.000838
# T13        0.008546  0.000213  0.027570  0.000995
# T14        0.044802  0.000213  0.009269  0.000087
# T15        0.019910  0.001249  0.002410  0.000087
# T16        0.032587  0.001427  0.038263  0.029490
# T17        0.018214  0.002142  0.018641  0.001457
# T18        0.012241  0.000984  0.015420  0.000087
# T19        0.000688  0.000213  0.000057  0.000087
# T20        0.000799  0.000213  0.000057  0.000087
# T21        0.012992  0.000235  0.013305  0.000087
# T22        0.004409  0.000213  0.012655  0.000087
# T23        0.018622  0.000213  0.035274  0.003855
# T24        0.000688  0.000213  0.000057  0.000087
# T25        0.016803  0.010743  0.035539  0.000087
# T26        0.032983  0.001487  0.076891  0.000087
# T27        0.062086  0.009129  0.105586  0.014797
# T28        0.038683  0.017333  0.001131  0.532763
# T29        0.000688  0.000213  0.000057  0.000087
# T30        0.058292  0.596143  0.008792  0.117924
# T31        0.020666  0.011390  0.007433  0.124680
# T32        0.012998  0.004511  0.016880  0.000087
# T33        0.084426  0.000845  0.071779  0.000902
# T34        0.028344  0.002839  0.024234  0.000875
# T35        0.028296  0.000213  0.005501  0.000087
# T36        0.001751  0.045359  0.000057  0.000716
# T37        0.025887  0.058281  0.035083  0.063087
# T38        0.042961  0.004280  0.059781  0.005841
# T39        0.004247  0.000213  0.014314  0.000087

# %%
TOPICS[AUTHORS + ['label']].style.background_gradient(cmap='GnBu', axis=None)
# Out:
# <style type="text/css">
# #T_2bd28_row0_col0, #T_2bd28_row0_col1, #T_2bd28_row0_col2, #T_2bd28_row1_col0, #T_2bd28_row1_col2, #T_2bd28_row2_col0, #T_2bd28_row2_col1, #T_2bd28_row2_col2, #T_2bd28_row3_col0, #T_2bd28_row3_col2, #T_2bd28_row4_col0, #T_2bd28_row5_col2, #T_2bd28_row6_col0, #T_2bd28_row6_col2, #T_2bd28_row8_col1, #T_2bd28_row9_col0, #T_2bd28_row9_col2, #T_2bd28_row10_col0, #T_2bd28_row10_col2, #T_2bd28_row12_col0, #T_2bd28_row12_col2, #T_2bd28_row13_col0, #T_2bd28_row13_col2, #T_2bd28_row14_col0, #T_2bd28_row14_col2, #T_2bd28_row15_col0, #T_2bd28_row15_col2, #T_2bd28_row16_col0, #T_2bd28_row17_col0, #T_2bd28_row17_col2, #T_2bd28_row18_col0, #T_2bd28_row18_col2, #T_2bd28_row19_col0, #T_2bd28_row19_col1, #T_2bd28_row19_col2, #T_2bd28_row20_col0, #T_2bd28_row20_col1, #T_2bd28_row20_col2, #T_2bd28_row21_col0, #T_2bd28_row21_col2, #T_2bd28_row22_col0, #T_2bd28_row22_col2, #T_2bd28_row23_col0, #T_2bd28_row24_col0, #T_2bd28_row24_col1, #T_2bd28_row24_col2, #T_2bd28_row25_col2, #T_2bd28_row26_col0, #T_2bd28_row26_col2, #T_2bd28_row28_col1, #T_2bd28_row29_col0, #T_2bd28_row29_col1, #T_2bd28_row29_col2, #T_2bd28_row32_col2, #T_2bd28_row33_col0, #T_2bd28_row33_col2, #T_2bd28_row34_col2, #T_2bd28_row35_col0, #T_2bd28_row35_col2, #T_2bd28_row36_col1, #T_2bd28_row36_col2, #T_2bd28_row39_col0, #T_2bd28_row39_col2 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_2bd28_row1_col1, #T_2bd28_row16_col1 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_2bd28_row3_col1, #T_2bd28_row27_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_2bd28_row4_col1, #T_2bd28_row8_col0, #T_2bd28_row10_col1, #T_2bd28_row18_col1, #T_2bd28_row27_col2, #T_2bd28_row39_col1 {
#   background-color: #f3faec;
#   color: #000000;
# }
# #T_2bd28_row4_col2, #T_2bd28_row5_col0, #T_2bd28_row15_col1, #T_2bd28_row23_col2, #T_2bd28_row32_col0, #T_2bd28_row34_col0, #T_2bd28_row38_col0 {
#   background-color: #f6fcef;
#   color: #000000;
# }
# #T_2bd28_row5_col1, #T_2bd28_row6_col1, #T_2bd28_row7_col2, #T_2bd28_row12_col1, #T_2bd28_row13_col1 {
#   background-color: #eff9e9;
#   color: #000000;
# }
# #T_2bd28_row7_col0 {
#   background-color: #f1faeb;
#   color: #000000;
# }
# #T_2bd28_row7_col1 {
#   background-color: #e9f6e3;
#   color: #000000;
# }
# #T_2bd28_row8_col2 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_2bd28_row9_col1, #T_2bd28_row23_col1, #T_2bd28_row25_col1, #T_2bd28_row37_col1 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_2bd28_row11_col0 {
#   background-color: #bce5be;
#   color: #000000;
# }
# #T_2bd28_row11_col1, #T_2bd28_row34_col1 {
#   background-color: #f0f9e9;
#   color: #000000;
# }
# #T_2bd28_row11_col2, #T_2bd28_row35_col1, #T_2bd28_row38_col2 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_2bd28_row14_col1, #T_2bd28_row27_col0, #T_2bd28_row30_col1, #T_2bd28_row31_col1 {
#   background-color: #f5fbee;
#   color: #000000;
# }
# #T_2bd28_row16_col2 {
#   background-color: #eef9e8;
#   color: #000000;
# }
# #T_2bd28_row17_col1, #T_2bd28_row28_col0, #T_2bd28_row32_col1 {
#   background-color: #f2faeb;
#   color: #000000;
# }
# #T_2bd28_row21_col1, #T_2bd28_row22_col1 {
#   background-color: #f3fbed;
#   color: #000000;
# }
# #T_2bd28_row25_col0, #T_2bd28_row31_col0 {
#   background-color: #f4fbed;
#   color: #000000;
# }
# #T_2bd28_row26_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_2bd28_row28_col2 {
#   background-color: #0862a5;
#   color: #f1f1f1;
# }
# #T_2bd28_row30_col0 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_2bd28_row30_col2 {
#   background-color: #d5eece;
#   color: #000000;
# }
# #T_2bd28_row31_col2 {
#   background-color: #d3eecc;
#   color: #000000;
# }
# #T_2bd28_row33_col1 {
#   background-color: #e1f4dc;
#   color: #000000;
# }
# #T_2bd28_row36_col0 {
#   background-color: #e9f7e3;
#   color: #000000;
# }
# #T_2bd28_row37_col0, #T_2bd28_row38_col1 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_2bd28_row37_col2 {
#   background-color: #e4f4de;
#   color: #000000;
# }
# </style>
# <table id="T_2bd28">
#   <thead>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th id="T_2bd28_level0_col0" class="col_heading level0 col0" >hobbes</th>
#       <th id="T_2bd28_level0_col1" class="col_heading level0 col1" >locke</th>
#       <th id="T_2bd28_level0_col2" class="col_heading level0 col2" >rousseau</th>
#       <th id="T_2bd28_level0_col3" class="col_heading level0 col3" >label</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bd28_level0_row0" class="row_heading level0 row0" >T00</th>
#       <td id="T_2bd28_row0_col0" class="data row0 col0" >0.000213</td>
#       <td id="T_2bd28_row0_col1" class="data row0 col1" >0.000057</td>
#       <td id="T_2bd28_row0_col2" class="data row0 col2" >0.000087</td>
#       <td id="T_2bd28_row0_col3" class="data row0 col3" >T00 aaron, pieces, person soveraign, persons, peru, peter, phantasme, phantasmes, philosopher</td>
#     </tr>
#     <tr>
#       <th id="T_2bd28_level0_row1" class="row_heading level0 row1" >T01</th>
#       <td id="T_2bd28_row1_col0" class="data row1 col0" >0.000213</td>
#       <td id="T_2bd28_row1_col1" class="data row1 col1" >0.038731</td>
#       <td id="T_2bd28_row1_col2" class="data row1 col2" >0.000087</td>
#       <td id="T_2bd28_row1_col3" class="data row1 col3" >T01 power, men, worship, man, god, commonwealth, image, lawes, actions</td>
#     </tr>
#     <tr>
#       <th id="T_2bd28_level0_row2" class="row_heading level0 row2" >T02</th>
#       <td id="T_2bd28_row2_col0" class="data row2 col0" >0.000213</td>
#       <td id="T_2bd28_row2_col1" class="data row2 col1" >0.000057</td>
#       <td id="T_2bd28_row2_col2" class="data row2 col2" >0.000087</td>
#       <td id="T_2bd28_row2_col3" class="data row2 col3" >T02 aaron, pieces, person soveraign, persons, peru, peter, phantasme, phantasmes, philosopher</td>
#     </tr>
#     <tr>
#       <th id="T_2bd28_level0_row3" class="row_heading level0 row3" >T03</th>
#       <td id="T_2bd28_row3_col0" class="data row3 col0" >0.001537</td>
#       <td id="T_2bd28_row3_col1" class="data row3 col1" >0.105662</td>
#       <td id="T_2bd28_row3_col2" class="data row3 col2" >0.000087</td>
#       <td id="T_2bd28_row3_col3" class="data row3 col3" >T03 ideas, idea, mind, things, substances, power, minds, modes, parts</td>
#     </tr>
#     <tr>
#       <th id="T_2bd28_level0_row4" class="row_heading level0 row4" >T04</th>
#       <td id="T_2bd28_row4_col0" class="data row4 col0" >0.000213</td>
#       <td id="T_2bd28_row4_col1" class="data row4 col1" >0.015066</td>
#       <td id="T_2bd28_row4_col2" class="data row4 col2" >0.002467</td>
#       <td id="T_2bd28_row4_col3" class="data row4 col3" >T04 words, ideas, names, use, signification, men, word, idea, things</td>
#     </tr>
#     <tr>
#       <th id="T_2bd28_level0_row5" class="row_heading level0 row5" >T05</th>
#       <td id="T_2bd28_row5_col0" class="data row5 col0" >0.003482</td>
#       <td id="T_2bd28_row5_col1" class="data row5 col1" >0.026983</td>
#       <td id="T_2bd28_row5_col2" class="data row5 col2" >0.000087</td>
#       <td id="T_2bd28_row5_col3" class="data row5 col3" >T05 god, spirit, sense, men, place, word, words, spirits, vision</td>
#     </tr>
#     <tr>
#       <th id="T_2bd28_level0_row6" class="row_heading level0 row6" >T06</th>
#       <td id="T_2bd28_row6_col0" class="data row6 col0" >0.002381</td>
#       <td id="T_2bd28_row6_col1" class="data row6 col1" >0.026306</td>
#       <td id="T_2bd28_row6_col2" class="data row6 col2" >0.001203</td>
#       <td id="T_2bd28_row6_col3" class="data row6 col3" >T06 ideas, relation, things, relations, idea, men, thing, man, actions</td>
#     </tr>
#     <tr>
#       <th id="T_2bd28_level0_row7" class="row_heading level0 row7" >T07</th>
#       <td id="T_2bd28_row7_col0" class="data row7 col0" >0.019882</td>
#       <td id="T_2bd28_row7_col1" class="data row7 col1" >0.047236</td>
#       <td id="T_2bd28_row7_col2" class="data row7 col2" >0.027523</td>
#       <td id="T_2

# %%
TOPICS[AUTHORS + ['label']].sort_values('hobbes', ascending=False).style.background_gradient(cmap='GnBu', axis=None)
# Out:
# <style type="text/css">
# #T_b51d5_row0_col0 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_b51d5_row0_col1, #T_b51d5_row7_col1, #T_b51d5_row9_col0, #T_b51d5_row34_col1 {
#   background-color: #f5fbee;
#   color: #000000;
# }
# #T_b51d5_row0_col2 {
#   background-color: #d5eece;
#   color: #000000;
# }
# #T_b51d5_row1_col0 {
#   background-color: #bce5be;
#   color: #000000;
# }
# #T_b51d5_row1_col1, #T_b51d5_row13_col1 {
#   background-color: #f0f9e9;
#   color: #000000;
# }
# #T_b51d5_row1_col2, #T_b51d5_row11_col2, #T_b51d5_row26_col1 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_b51d5_row2_col0, #T_b51d5_row11_col1 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_b51d5_row2_col1, #T_b51d5_row8_col1, #T_b51d5_row19_col1, #T_b51d5_row30_col1 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_b51d5_row2_col2 {
#   background-color: #e4f4de;
#   color: #000000;
# }
# #T_b51d5_row3_col0 {
#   background-color: #e9f7e3;
#   color: #000000;
# }
# #T_b51d5_row3_col1, #T_b51d5_row3_col2, #T_b51d5_row5_col1, #T_b51d5_row6_col1, #T_b51d5_row8_col2, #T_b51d5_row10_col2, #T_b51d5_row12_col2, #T_b51d5_row13_col2, #T_b51d5_row14_col0, #T_b51d5_row14_col2, #T_b51d5_row15_col0, #T_b51d5_row15_col2, #T_b51d5_row16_col0, #T_b51d5_row16_col2, #T_b51d5_row17_col0, #T_b51d5_row17_col2, #T_b51d5_row18_col0, #T_b51d5_row18_col2, #T_b51d5_row19_col0, #T_b51d5_row19_col2, #T_b51d5_row20_col0, #T_b51d5_row21_col0, #T_b51d5_row21_col2, #T_b51d5_row22_col0, #T_b51d5_row22_col2, #T_b51d5_row23_col0, #T_b51d5_row23_col2, #T_b51d5_row24_col0, #T_b51d5_row24_col2, #T_b51d5_row25_col0, #T_b51d5_row25_col2, #T_b51d5_row26_col0, #T_b51d5_row26_col2, #T_b51d5_row27_col0, #T_b51d5_row27_col1, #T_b51d5_row27_col2, #T_b51d5_row28_col0, #T_b51d5_row28_col1, #T_b51d5_row28_col2, #T_b51d5_row29_col0, #T_b51d5_row29_col1, #T_b51d5_row29_col2, #T_b51d5_row30_col0, #T_b51d5_row31_col0, #T_b51d5_row31_col2, #T_b51d5_row32_col0, #T_b51d5_row32_col2, #T_b51d5_row33_col0, #T_b51d5_row33_col1, #T_b51d5_row33_col2, #T_b51d5_row34_col0, #T_b51d5_row34_col2, #T_b51d5_row35_col0, #T_b51d5_row35_col2, #T_b51d5_row36_col0, #T_b51d5_row36_col2, #T_b51d5_row37_col0, #T_b51d5_row38_col0, #T_b51d5_row38_col1, #T_b51d5_row38_col2, #T_b51d5_row39_col0, #T_b51d5_row39_col1, #T_b51d5_row39_col2 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_b51d5_row4_col0 {
#   background-color: #f1faeb;
#   color: #000000;
# }
# #T_b51d5_row4_col1 {
#   background-color: #e9f6e3;
#   color: #000000;
# }
# #T_b51d5_row4_col2, #T_b51d5_row12_col1, #T_b51d5_row14_col1, #T_b51d5_row16_col1, #T_b51d5_row35_col1 {
#   background-color: #eff9e9;
#   color: #000000;
# }
# #T_b51d5_row5_col0, #T_b51d5_row10_col1, #T_b51d5_row15_col1 {
#   background-color: #f2faeb;
#   color: #000000;
# }
# #T_b51d5_row5_col2 {
#   background-color: #0862a5;
#   color: #f1f1f1;
# }
# #T_b51d5_row6_col0, #T_b51d5_row9_col2, #T_b51d5_row22_col1, #T_b51d5_row25_col1, #T_b51d5_row36_col1, #T_b51d5_row37_col1 {
#   background-color: #f3faec;
#   color: #000000;
# }
# #T_b51d5_row6_col2 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_b51d5_row7_col0, #T_b51d5_row8_col0 {
#   background-color: #f4fbed;
#   color: #000000;
# }
# #T_b51d5_row7_col2 {
#   background-color: #d3eecc;
#   color: #000000;
# }
# #T_b51d5_row9_col1, #T_b51d5_row17_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_b51d5_row10_col0, #T_b51d5_row11_col0, #T_b51d5_row12_col0, #T_b51d5_row13_col0, #T_b51d5_row21_col1, #T_b51d5_row30_col2, #T_b51d5_row37_col2 {
#   background-color: #f6fcef;
#   color: #000000;
# }
# #T_b51d5_row18_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_b51d5_row20_col1, #T_b51d5_row32_col1 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_b51d5_row20_col2 {
#   background-color: #eef9e8;
#   color: #000000;
# }
# #T_b51d5_row23_col1 {
#   background-color: #e1f4dc;
#   color: #000000;
# }
# #T_b51d5_row24_col1, #T_b51d5_row31_col1 {
#   background-color: #f3fbed;
#   color: #000000;
# }
# </style>
# <table id="T_b51d5">
#   <thead>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th id="T_b51d5_level0_col0" class="col_heading level0 col0" >hobbes</th>
#       <th id="T_b51d5_level0_col1" class="col_heading level0 col1" >locke</th>
#       <th id="T_b51d5_level0_col2" class="col_heading level0 col2" >rousseau</th>
#       <th id="T_b51d5_level0_col3" class="col_heading level0 col3" >label</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b51d5_level0_row0" class="row_heading level0 row0" >T30</th>
#       <td id="T_b51d5_row0_col0" class="data row0 col0" >0.596143</td>
#       <td id="T_b51d5_row0_col1" class="data row0 col1" >0.008792</td>
#       <td id="T_b51d5_row0_col2" class="data row0 col2" >0.117924</td>
#       <td id="T_b51d5_row0_col3" class="data row0 col3" >T30 government, people, state, body, laws, power, authority, sovereign, prince</td>
#     </tr>
#     <tr>
#       <th id="T_b51d5_level0_row1" class="row_heading level0 row1" >T11</th>
#       <td id="T_b51d5_row1_col0" class="data row1 col0" >0.182510</td>
#       <td id="T_b51d5_row1_col1" class="data row1 col1" >0.024716</td>
#       <td id="T_b51d5_row1_col2" class="data row1 col2" >0.005894</td>
#       <td id="T_b51d5_row1_col3" class="data row1 col3" >T11 men, man, state, nature, laws, society, life, time, people</td>
#     </tr>
#     <tr>
#       <th id="T_b51d5_level0_row2" class="row_heading level0 row2" >T37</th>
#       <td id="T_b51d5_row2_col0" class="data row2 col0" >0.058281</td>
#       <td id="T_b51d5_row2_col1" class="data row2 col1" >0.035083</td>
#       <td id="T_b51d5_row2_col2" class="data row2 col2" >0.063087</td>
#       <td id="T_b51d5_row2_col3" class="data row2 col3" >T37 right, man, nature, liberty, covenant, men, war, law, life</td>
#     </tr>
#     <tr>
#       <th id="T_b51d5_level0_row3" class="row_heading level0 row3" >T36</th>
#       <td id="T_b51d5_row3_col0" class="data row3 col0" >0.045359</td>
#       <td id="T_b51d5_row3_col1" class="data row3 col1" >0.000057</td>
#       <td id="T_b51d5_row3_col2" class="data row3 col2" >0.000716</td>
#       <td id="T_b51d5_row3_col3" class="data row3 col3" >T36 people, interests, associations, differences, agreement, society, man, societies, act</td>
#     </tr>
#     <tr>
#       <th id="T_b51d5_level0_row4" class="row_heading level0 row4" >T07</th>
#       <td id="T_b51d5_row4_col0" class="data row4 col0" >0.019882</td>
#       <td id="T_b51d5_row4_col1" class="data row4 col1" >0.047236</td>
#       <td id="T_b51d5_row4_col2" class="data row4 col2" >0.027523</td>
#       <td id="T_b51d5_row4_col3" class="data row4 col3" >T07 law, man, nature, men, lawes, crime, commonwealth, law nature, reason</td>
#     </tr>
#     <tr>
#       <th id="T_b51d5_level0_row5" class="row_heading level0 row5" >T28</th>
#       <td id="T_b51d5_row5_col0" class="data row5 col0" >0.017333</td>
#       <td id="T_b51d5_row5_col1" class="data row5 col1" >0.001131</td>
#       <td id="T_b51d5_row5_col2" class="data row5 col2" >0.532763</td>
#       <td id="T_b51d5_row5_col3" class="data row5 col3" >T28 power, society, state, laws, people, men, nature, force, state nature</td>
#     </tr>
#     <tr>
#       <th id="T_b51d5_level0_row6" class="row_heading level0 row6" >T08</th>
#       <td id="T_b51d5_row6_col0" class="data row6 col0" >0.015502</td>
#       <td id="T_b51d5_row6_col1" class="data row6 col1" >0.001588</td>
#       <td id="T_b51d5_row6_col2" class="data row6 col2" >0.062867</td>
#       <td id="T_b51d5_row6_col3" class="data row6 col3" >T08 property, land, use, labour, right, men, man, life, nature</td>
#     </tr>
#     <tr>
#       <th id="T_b51d5_level0_row7" class="row_heading level0 row7" >T31</th>
#       <td id="T_b51d5_row7_col0" class="data row7 col0" >0.011390</td>
#       <td id="T_b51d5_row7_col1" class="data row7 col1" >0.007433</td>
#       <td id="T_b51d5_row7_col2" class="data row7 col2" >0.124680</td>
#       <td id="T_b51d5_row7_col3" class="data

# %%
TOPICS[AUTHORS + ['label']].sort_values('locke', ascending=False).style.background_gradient(cmap='GnBu', axis=None)
# Out:
# <style type="text/css">
# #T_41a2a_row0_col0, #T_41a2a_row0_col2, #T_41a2a_row2_col0, #T_41a2a_row2_col2, #T_41a2a_row3_col0, #T_41a2a_row3_col2, #T_41a2a_row6_col0, #T_41a2a_row6_col2, #T_41a2a_row7_col0, #T_41a2a_row8_col0, #T_41a2a_row8_col2, #T_41a2a_row9_col2, #T_41a2a_row10_col0, #T_41a2a_row12_col0, #T_41a2a_row12_col2, #T_41a2a_row13_col2, #T_41a2a_row14_col0, #T_41a2a_row14_col2, #T_41a2a_row15_col0, #T_41a2a_row15_col2, #T_41a2a_row17_col2, #T_41a2a_row18_col0, #T_41a2a_row18_col2, #T_41a2a_row19_col2, #T_41a2a_row20_col0, #T_41a2a_row20_col2, #T_41a2a_row21_col0, #T_41a2a_row21_col2, #T_41a2a_row22_col0, #T_41a2a_row23_col0, #T_41a2a_row23_col2, #T_41a2a_row24_col0, #T_41a2a_row24_col2, #T_41a2a_row25_col0, #T_41a2a_row25_col2, #T_41a2a_row26_col0, #T_41a2a_row26_col2, #T_41a2a_row29_col0, #T_41a2a_row29_col2, #T_41a2a_row30_col0, #T_41a2a_row30_col2, #T_41a2a_row31_col1, #T_41a2a_row32_col1, #T_41a2a_row33_col1, #T_41a2a_row33_col2, #T_41a2a_row34_col0, #T_41a2a_row34_col1, #T_41a2a_row34_col2, #T_41a2a_row35_col0, #T_41a2a_row35_col1, #T_41a2a_row35_col2, #T_41a2a_row36_col0, #T_41a2a_row36_col1, #T_41a2a_row36_col2, #T_41a2a_row37_col0, #T_41a2a_row37_col1, #T_41a2a_row37_col2, #T_41a2a_row38_col0, #T_41a2a_row38_col1, #T_41a2a_row38_col2, #T_41a2a_row39_col0, #T_41a2a_row39_col1, #T_41a2a_row39_col2 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_41a2a_row0_col1, #T_41a2a_row1_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_41a2a_row1_col0, #T_41a2a_row26_col1, #T_41a2a_row27_col1, #T_41a2a_row28_col1 {
#   background-color: #f5fbee;
#   color: #000000;
# }
# #T_41a2a_row1_col2, #T_41a2a_row20_col1, #T_41a2a_row21_col1, #T_41a2a_row22_col1, #T_41a2a_row23_col1, #T_41a2a_row31_col0 {
#   background-color: #f3faec;
#   color: #000000;
# }
# #T_41a2a_row2_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_41a2a_row3_col1 {
#   background-color: #e1f4dc;
#   color: #000000;
# }
# #T_41a2a_row4_col0, #T_41a2a_row10_col2, #T_41a2a_row13_col0, #T_41a2a_row17_col0, #T_41a2a_row19_col0, #T_41a2a_row22_col2, #T_41a2a_row30_col1 {
#   background-color: #f6fcef;
#   color: #000000;
# }
# #T_41a2a_row4_col1, #T_41a2a_row11_col0 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_41a2a_row4_col2, #T_41a2a_row16_col2, #T_41a2a_row29_col1 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_41a2a_row5_col0 {
#   background-color: #f1faeb;
#   color: #000000;
# }
# #T_41a2a_row5_col1 {
#   background-color: #e9f6e3;
#   color: #000000;
# }
# #T_41a2a_row5_col2, #T_41a2a_row12_col1, #T_41a2a_row13_col1, #T_41a2a_row14_col1, #T_41a2a_row15_col1 {
#   background-color: #eff9e9;
#   color: #000000;
# }
# #T_41a2a_row6_col1, #T_41a2a_row7_col1 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_41a2a_row7_col2 {
#   background-color: #eef9e8;
#   color: #000000;
# }
# #T_41a2a_row8_col1, #T_41a2a_row9_col1, #T_41a2a_row10_col1, #T_41a2a_row11_col1 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_41a2a_row9_col0, #T_41a2a_row28_col0 {
#   background-color: #f4fbed;
#   color: #000000;
# }
# #T_41a2a_row11_col2 {
#   background-color: #e4f4de;
#   color: #000000;
# }
# #T_41a2a_row16_col0 {
#   background-color: #bce5be;
#   color: #000000;
# }
# #T_41a2a_row16_col1, #T_41a2a_row17_col1 {
#   background-color: #f0f9e9;
#   color: #000000;
# }
# #T_41a2a_row18_col1, #T_41a2a_row19_col1, #T_41a2a_row32_col0 {
#   background-color: #f2faeb;
#   color: #000000;
# }
# #T_41a2a_row24_col1, #T_41a2a_row25_col1 {
#   background-color: #f3fbed;
#   color: #000000;
# }
# #T_41a2a_row27_col0 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_41a2a_row27_col2 {
#   background-color: #d5eece;
#   color: #000000;
# }
# #T_41a2a_row28_col2 {
#   background-color: #d3eecc;
#   color: #000000;
# }
# #T_41a2a_row31_col2 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_41a2a_row32_col2 {
#   background-color: #0862a5;
#   color: #f1f1f1;
# }
# #T_41a2a_row33_col0 {
#   background-color: #e9f7e3;
#   color: #000000;
# }
# </style>
# <table id="T_41a2a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th id="T_41a2a_level0_col0" class="col_heading level0 col0" >hobbes</th>
#       <th id="T_41a2a_level0_col1" class="col_heading level0 col1" >locke</th>
#       <th id="T_41a2a_level0_col2" class="col_heading level0 col2" >rousseau</th>
#       <th id="T_41a2a_level0_col3" class="col_heading level0 col3" >label</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_41a2a_level0_row0" class="row_heading level0 row0" >T03</th>
#       <td id="T_41a2a_row0_col0" class="data row0 col0" >0.001537</td>
#       <td id="T_41a2a_row0_col1" class="data row0 col1" >0.105662</td>
#       <td id="T_41a2a_row0_col2" class="data row0 col2" >0.000087</td>
#       <td id="T_41a2a_row0_col3" class="data row0 col3" >T03 ideas, idea, mind, things, substances, power, minds, modes, parts</td>
#     </tr>
#     <tr>
#       <th id="T_41a2a_level0_row1" class="row_heading level0 row1" >T27</th>
#       <td id="T_41a2a_row1_col0" class="data row1 col0" >0.009129</td>
#       <td id="T_41a2a_row1_col1" class="data row1 col1" >0.105586</td>
#       <td id="T_41a2a_row1_col2" class="data row1 col2" >0.014797</td>
#       <td id="T_41a2a_row1_col3" class="data row1 col3" >T27 men, power, man, time, things, right, reason, nature, people</td>
#     </tr>
#     <tr>
#       <th id="T_41a2a_level0_row2" class="row_heading level0 row2" >T26</th>
#       <td id="T_41a2a_row2_col0" class="data row2 col0" >0.001487</td>
#       <td id="T_41a2a_row2_col1" class="data row2 col1" >0.076891</td>
#       <td id="T_41a2a_row2_col2" class="data row2 col2" >0.000087</td>
#       <td id="T_41a2a_row2_col3" class="data row2 col3" >T26 ideas, qualities, motion, senses, mind, bodies, man, soul, objects</td>
#     </tr>
#     <tr>
#       <th id="T_41a2a_level0_row3" class="row_heading level0 row3" >T33</th>
#       <td id="T_41a2a_row3_col0" class="data row3 col0" >0.000845</td>
#       <td id="T_41a2a_row3_col1" class="data row3 col1" >0.071779</td>
#       <td id="T_41a2a_row3_col2" class="data row3 col2" >0.000902</td>
#       <td id="T_41a2a_row3_col3" class="data row3 col3" >T33 god, christ, church, man, power, kingdome, men, saviour, apostles</td>
#     </tr>
#     <tr>
#       <th id="T_41a2a_level0_row4" class="row_heading level0 row4" >T38</th>
#       <td id="T_41a2a_row4_col0" class="data row4 col0" >0.004280</td>
#       <td id="T_41a2a_row4_col1" class="data row4 col1" >0.059781</td>
#       <td id="T_41a2a_row4_col2" class="data row4 col2" >0.005841</td>
#       <td id="T_41a2a_row4_col3" class="data row4 col3" >T38 man, matter, things, thing, men, knowledge, thoughts, probability, reason</td>
#     </tr>
#     <tr>
#       <th id="T_41a2a_level0_row5" class="row_heading level0 row5" >T07</th>
#       <td id="T_41a2a_row5_col0" class="data row5 col0" >0.019882</td>
#       <td id="T_41a2a_row5_col1" class="data row5 col1" >0.047236</td>
#       <td id="T_41a2a_row5_col2" class="data row5 col2" >0.027523</td>
#       <td id="T_41a2a_row5_col3" class="data row5 col3" >T07 law, man, nature, men, lawes, crime, commonwealth, law nature, reason</td>
#     </tr>
#     <tr>
#       <th id="T_41a2a_level0_row6" class="row_heading level0 row6" >T01</th>
#       <td id="T_41a2a_row6_col0" class="data row6 col0" >0.000213</td>
#       <td id="T_41a2a_row6_col1" class="data row6 col1" >0.038731</td>
#       <td id="T_41a2a_row6_col2" class="data row6 col2" >0.000087</td>
#       <td id="T_41a2a_row6_col3" class="data row6 col3" >T01 power, men, worship, man, god, commonwealth, image, lawes, actions</td>
#     </tr>
#     <tr>
#       <th id="T_41a2a_level0_row7" class="row_heading level0 row7" >T16</th>
#       <td id="T_41a2a_row7_col0" class="data row7 col0" >0.001427</td>
#       <td id="T_41a2a_row7_col1" class="data row7 col1" >0.038263</td>
#       <td id="T_41a2a_row7_col2" class="data row7 col2" >0.029490</td>
#       <td id="T_41a2a_row7_col3" class="data row7 co

# %%
TOPICS[AUTHORS + ['label']].sort_values('rousseau', ascending=False).style.background_gradient(cmap='GnBu', axis=None)
# Out:
# <style type="text/css">
# #T_eed94_row0_col0, #T_eed94_row12_col1, #T_eed94_row20_col1 {
#   background-color: #f2faeb;
#   color: #000000;
# }
# #T_eed94_row0_col1, #T_eed94_row4_col1, #T_eed94_row5_col0, #T_eed94_row10_col0, #T_eed94_row11_col0, #T_eed94_row12_col0, #T_eed94_row12_col2, #T_eed94_row13_col0, #T_eed94_row13_col2, #T_eed94_row14_col0, #T_eed94_row14_col2, #T_eed94_row15_col0, #T_eed94_row15_col2, #T_eed94_row16_col2, #T_eed94_row17_col0, #T_eed94_row17_col2, #T_eed94_row18_col1, #T_eed94_row18_col2, #T_eed94_row19_col2, #T_eed94_row20_col2, #T_eed94_row21_col0, #T_eed94_row21_col2, #T_eed94_row22_col0, #T_eed94_row22_col2, #T_eed94_row23_col0, #T_eed94_row23_col2, #T_eed94_row24_col0, #T_eed94_row24_col2, #T_eed94_row25_col0, #T_eed94_row25_col2, #T_eed94_row26_col0, #T_eed94_row26_col2, #T_eed94_row27_col2, #T_eed94_row28_col0, #T_eed94_row28_col2, #T_eed94_row29_col0, #T_eed94_row29_col1, #T_eed94_row29_col2, #T_eed94_row30_col0, #T_eed94_row30_col1, #T_eed94_row30_col2, #T_eed94_row31_col0, #T_eed94_row31_col2, #T_eed94_row32_col0, #T_eed94_row32_col1, #T_eed94_row32_col2, #T_eed94_row33_col0, #T_eed94_row33_col2, #T_eed94_row34_col0, #T_eed94_row34_col1, #T_eed94_row34_col2, #T_eed94_row35_col0, #T_eed94_row35_col2, #T_eed94_row36_col0, #T_eed94_row36_col2, #T_eed94_row37_col0, #T_eed94_row37_col2, #T_eed94_row38_col0, #T_eed94_row38_col1, #T_eed94_row38_col2, #T_eed94_row39_col0, #T_eed94_row39_col1, #T_eed94_row39_col2 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_eed94_row0_col2 {
#   background-color: #0862a5;
#   color: #f1f1f1;
# }
# #T_eed94_row1_col0, #T_eed94_row19_col0 {
#   background-color: #f4fbed;
#   color: #000000;
# }
# #T_eed94_row1_col1, #T_eed94_row2_col1, #T_eed94_row7_col0, #T_eed94_row28_col1 {
#   background-color: #f5fbee;
#   color: #000000;
# }
# #T_eed94_row1_col2 {
#   background-color: #d3eecc;
#   color: #000000;
# }
# #T_eed94_row2_col0 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_eed94_row2_col2 {
#   background-color: #d5eece;
#   color: #000000;
# }
# #T_eed94_row3_col0, #T_eed94_row9_col1 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_eed94_row3_col1, #T_eed94_row10_col1, #T_eed94_row19_col1, #T_eed94_row36_col1 {
#   background-color: #ecf8e6;
#   color: #000000;
# }
# #T_eed94_row3_col2 {
#   background-color: #e4f4de;
#   color: #000000;
# }
# #T_eed94_row4_col0, #T_eed94_row7_col2, #T_eed94_row11_col1, #T_eed94_row21_col1, #T_eed94_row24_col1, #T_eed94_row35_col1 {
#   background-color: #f3faec;
#   color: #000000;
# }
# #T_eed94_row4_col2 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_eed94_row5_col1, #T_eed94_row23_col1 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_eed94_row5_col2 {
#   background-color: #eef9e8;
#   color: #000000;
# }
# #T_eed94_row6_col0 {
#   background-color: #f1faeb;
#   color: #000000;
# }
# #T_eed94_row6_col1 {
#   background-color: #e9f6e3;
#   color: #000000;
# }
# #T_eed94_row6_col2, #T_eed94_row13_col1, #T_eed94_row14_col1, #T_eed94_row17_col1, #T_eed94_row27_col1 {
#   background-color: #eff9e9;
#   color: #000000;
# }
# #T_eed94_row7_col1, #T_eed94_row37_col1 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_eed94_row8_col0 {
#   background-color: #bce5be;
#   color: #000000;
# }
# #T_eed94_row8_col1, #T_eed94_row16_col1 {
#   background-color: #f0f9e9;
#   color: #000000;
# }
# #T_eed94_row8_col2, #T_eed94_row9_col2, #T_eed94_row26_col1 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_eed94_row9_col0, #T_eed94_row10_col2, #T_eed94_row11_col2, #T_eed94_row16_col0, #T_eed94_row20_col0, #T_eed94_row25_col1, #T_eed94_row27_col0 {
#   background-color: #f6fcef;
#   color: #000000;
# }
# #T_eed94_row15_col1 {
#   background-color: #e1f4dc;
#   color: #000000;
# }
# #T_eed94_row18_col0 {
#   background-color: #e9f7e3;
#   color: #000000;
# }
# #T_eed94_row22_col1, #T_eed94_row33_col1 {
#   background-color: #f3fbed;
#   color: #000000;
# }
# #T_eed94_row31_col1 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# </style>
# <table id="T_eed94">
#   <thead>
#     <tr>
#       <th class="index_name level0" >term_str</th>
#       <th id="T_eed94_level0_col0" class="col_heading level0 col0" >hobbes</th>
#       <th id="T_eed94_level0_col1" class="col_heading level0 col1" >locke</th>
#       <th id="T_eed94_level0_col2" class="col_heading level0 col2" >rousseau</th>
#       <th id="T_eed94_level0_col3" class="col_heading level0 col3" >label</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >topic_id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eed94_level0_row0" class="row_heading level0 row0" >T28</th>
#       <td id="T_eed94_row0_col0" class="data row0 col0" >0.017333</td>
#       <td id="T_eed94_row0_col1" class="data row0 col1" >0.001131</td>
#       <td id="T_eed94_row0_col2" class="data row0 col2" >0.532763</td>
#       <td id="T_eed94_row0_col3" class="data row0 col3" >T28 power, society, state, laws, people, men, nature, force, state nature</td>
#     </tr>
#     <tr>
#       <th id="T_eed94_level0_row1" class="row_heading level0 row1" >T31</th>
#       <td id="T_eed94_row1_col0" class="data row1 col0" >0.011390</td>
#       <td id="T_eed94_row1_col1" class="data row1 col1" >0.007433</td>
#       <td id="T_eed94_row1_col2" class="data row1 col2" >0.124680</td>
#       <td id="T_eed94_row1_col3" class="data row1 col3" >T31 children, father, power, man, law, parents, reason, nature, government</td>
#     </tr>
#     <tr>
#       <th id="T_eed94_level0_row2" class="row_heading level0 row2" >T30</th>
#       <td id="T_eed94_row2_col0" class="data row2 col0" >0.596143</td>
#       <td id="T_eed94_row2_col1" class="data row2 col1" >0.008792</td>
#       <td id="T_eed94_row2_col2" class="data row2 col2" >0.117924</td>
#       <td id="T_eed94_row2_col3" class="data row2 col3" >T30 government, people, state, body, laws, power, authority, sovereign, prince</td>
#     </tr>
#     <tr>
#       <th id="T_eed94_level0_row3" class="row_heading level0 row3" >T37</th>
#       <td id="T_eed94_row3_col0" class="data row3 col0" >0.058281</td>
#       <td id="T_eed94_row3_col1" class="data row3 col1" >0.035083</td>
#       <td id="T_eed94_row3_col2" class="data row3 col2" >0.063087</td>
#       <td id="T_eed94_row3_col3" class="data row3 col3" >T37 right, man, nature, liberty, covenant, men, war, law, life</td>
#     </tr>
#     <tr>
#       <th id="T_eed94_level0_row4" class="row_heading level0 row4" >T08</th>
#       <td id="T_eed94_row4_col0" class="data row4 col0" >0.015502</td>
#       <td id="T_eed94_row4_col1" class="data row4 col1" >0.001588</td>
#       <td id="T_eed94_row4_col2" class="data row4 col2" >0.062867</td>
#       <td id="T_eed94_row4_col3" class="data row4 col3" >T08 property, land, use, labour, right, men, man, life, nature</td>
#     </tr>
#     <tr>
#       <th id="T_eed94_level0_row5" class="row_heading level0 row5" >T16</th>
#       <td id="T_eed94_row5_col0" class="data row5 col0" >0.001427</td>
#       <td id="T_eed94_row5_col1" class="data row5 col1" >0.038263</td>
#       <td id="T_eed94_row5_col2" class="data row5 col2" >0.029490</td>
#       <td id="T_eed94_row5_col3" class="data row5 col3" >T16 power, action, pleasure, mind, pain, man, happiness, desire, liberty</td>
#     </tr>
#     <tr>
#       <th id="T_eed94_level0_row6" class="row_heading level0 row6" >T07</th>
#       <td id="T_eed94_row6_col0" class="data row6 col0" >0.019882</td>
#       <td id="T_eed94_row6_col1" class="data row6 col1" >0.047236</td>
#       <td id="T_eed94_row6_col2" class="data row6 col2" >0.027523</td>
#       <td id="T_eed94_row6_col3" class="data row6 col3" >T07 law, man, nature, men, lawes, crime, commonwealth, law nature, reason</td>
#     </tr>
#     <tr>
#       <th id="T_eed94_level0_row7" class="row_heading level0 row7" >T27</th>
#       <td id="T_eed94_row7_col0" class="data row7 col0" >0.009129</td>
#       <td id="T_eed94_row7_col1" class="data row7 col1" >0.105586</td>
#       <td id="T_eed94_row7_col2" class="data row7 col2" >0.014797</td>
#       <td id="T_eed94_row7_col3" class="data row7

# %%
TOPICS['author'] = TOPICS[AUTHORS].idxmax(1)

# %%
TOPICS.iloc[:, 9:].sort_values(['author','doc_weight_sum'], ascending=[True,False]).style.background_gradient(cmap='GnBu')
# Out:
# <style type="text/css">
# #T_91909_row0_col1, #T_91909_row0_col3, #T_91909_row1_col2, #T_91909_row9_col4, #T_91909_row10_col4, #T_91909_row36_col5 {
#   background-color: #084081;
#   color: #f1f1f1;
# }
# #T_91909_row0_col2 {
#   background-color: #6bc3c9;
#   color: #000000;
# }
# #T_91909_row0_col4 {
#   background-color: #e8f6e2;
#   color: #000000;
# }
# #T_91909_row0_col5, #T_91909_row37_col1 {
#   background-color: #d1edca;
#   color: #000000;
# }
# #T_91909_row1_col1 {
#   background-color: #aedfb8;
#   color: #000000;
# }
# #T_91909_row1_col3, #T_91909_row10_col1, #T_91909_row13_col2 {
#   background-color: #bce5be;
#   color: #000000;
# }
# #T_91909_row1_col4, #T_91909_row38_col5 {
#   background-color: #cfecc8;
#   color: #000000;
# }
# #T_91909_row1_col5, #T_91909_row2_col2, #T_91909_row11_col5, #T_91909_row36_col4 {
#   background-color: #f6fbef;
#   color: #000000;
# }
# #T_91909_row2_col1, #T_91909_row29_col1, #T_91909_row38_col4, #T_91909_row39_col1 {
#   background-color: #ebf7e5;
#   color: #000000;
# }
# #T_91909_row2_col3, #T_91909_row27_col1, #T_91909_row28_col1, #T_91909_row28_col2 {
#   background-color: #e9f7e3;
#   color: #000000;
# }
# #T_91909_row2_col4, #T_91909_row2_col5, #T_91909_row3_col1, #T_91909_row3_col2, #T_91909_row3_col3, #T_91909_row3_col4, #T_91909_row3_col5, #T_91909_row4_col1, #T_91909_row4_col2, #T_91909_row4_col3, #T_91909_row4_col4, #T_91909_row4_col5, #T_91909_row5_col1, #T_91909_row5_col2, #T_91909_row5_col3, #T_91909_row5_col4, #T_91909_row5_col5, #T_91909_row6_col1, #T_91909_row6_col2, #T_91909_row6_col3, #T_91909_row6_col4, #T_91909_row6_col5, #T_91909_row7_col1, #T_91909_row7_col2, #T_91909_row7_col3, #T_91909_row7_col4, #T_91909_row7_col5, #T_91909_row8_col1, #T_91909_row8_col2, #T_91909_row8_col3, #T_91909_row8_col4, #T_91909_row8_col5, #T_91909_row9_col3, #T_91909_row9_col5, #T_91909_row12_col3, #T_91909_row13_col3, #T_91909_row13_col5, #T_91909_row14_col3, #T_91909_row14_col5, #T_91909_row16_col3, #T_91909_row16_col5, #T_91909_row17_col3, #T_91909_row17_col5, #T_91909_row18_col5, #T_91909_row19_col3, #T_91909_row19_col5, #T_91909_row20_col3, #T_91909_row21_col5, #T_91909_row22_col3, #T_91909_row22_col5, #T_91909_row23_col3, #T_91909_row23_col5, #T_91909_row24_col3, #T_91909_row24_col5, #T_91909_row25_col3, #T_91909_row26_col3, #T_91909_row26_col5, #T_91909_row27_col5, #T_91909_row28_col3, #T_91909_row28_col5, #T_91909_row29_col3, #T_91909_row29_col5, #T_91909_row30_col5, #T_91909_row31_col3, #T_91909_row31_col5, #T_91909_row32_col3, #T_91909_row32_col5, #T_91909_row33_col3, #T_91909_row33_col5, #T_91909_row34_col3, #T_91909_row34_col5, #T_91909_row35_col3, #T_91909_row35_col5 {
#   background-color: #f7fcf0;
#   color: #000000;
# }
# #T_91909_row9_col1, #T_91909_row20_col4, #T_91909_row36_col2 {
#   background-color: #acdfb7;
#   color: #000000;
# }
# #T_91909_row9_col2 {
#   background-color: #8dd3be;
#   color: #000000;
# }
# #T_91909_row10_col2 {
#   background-color: #5dbbce;
#   color: #000000;
# }
# #T_91909_row10_col3, #T_91909_row39_col4 {
#   background-color: #f5fbee;
#   color: #000000;
# }
# #T_91909_row10_col5, #T_91909_row36_col3 {
#   background-color: #f2faeb;
#   color: #000000;
# }
# #T_91909_row11_col1 {
#   background-color: #c0e6c0;
#   color: #000000;
# }
# #T_91909_row11_col2 {
#   background-color: #9fdab8;
#   color: #000000;
# }
# #T_91909_row11_col3, #T_91909_row12_col5, #T_91909_row18_col3, #T_91909_row25_col5, #T_91909_row27_col3, #T_91909_row30_col3 {
#   background-color: #f6fcef;
#   color: #000000;
# }
# #T_91909_row11_col4 {
#   background-color: #64bfcc;
#   color: #000000;
# }
# #T_91909_row12_col1 {
#   background-color: #c5e8c2;
#   color: #000000;
# }
# #T_91909_row12_col2 {
#   background-color: #83cfc1;
#   color: #000000;
# }
# #T_91909_row12_col4 {
#   background-color: #ddf2d8;
#   color: #000000;
# }
# #T_91909_row13_col1, #T_91909_row37_col2 {
#   background-color: #ceecc7;
#   color: #000000;
# }
# #T_91909_row13_col4 {
#   background-color: #3192c1;
#   color: #f1f1f1;
# }
# #T_91909_row14_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_91909_row14_col2 {
#   background-color: #1e7fb7;
#   color: #f1f1f1;
# }
# #T_91909_row14_col4 {
#   background-color: #3fa2ca;
#   color: #f1f1f1;
# }
# #T_91909_row15_col1 {
#   background-color: #d8f0d3;
#   color: #000000;
# }
# #T_91909_row15_col2 {
#   background-color: #9cd9b9;
#   color: #000000;
# }
# #T_91909_row15_col3, #T_91909_row31_col2, #T_91909_row33_col2, #T_91909_row35_col1 {
#   background-color: #f1faeb;
#   color: #000000;
# }
# #T_91909_row15_col4 {
#   background-color: #8ed3be;
#   color: #000000;
# }
# #T_91909_row15_col5, #T_91909_row16_col4, #T_91909_row30_col1 {
#   background-color: #eef8e7;
#   color: #000000;
# }
# #T_91909_row16_col1, #T_91909_row25_col2, #T_91909_row27_col2 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_91909_row16_col2, #T_91909_row18_col2 {
#   background-color: #c8eac3;
#   color: #000000;
# }
# #T_91909_row17_col1 {
#   background-color: #def2d9;
#   color: #000000;
# }
# #T_91909_row17_col2 {
#   background-color: #98d7ba;
#   color: #000000;
# }
# #T_91909_row17_col4 {
#   background-color: #e7f6e2;
#   color: #000000;
# }
# #T_91909_row18_col1, #T_91909_row33_col4 {
#   background-color: #dff2da;
#   color: #000000;
# }
# #T_91909_row18_col4 {
#   background-color: #d0ecc9;
#   color: #000000;
# }
# #T_91909_row19_col1, #T_91909_row34_col4 {
#   background-color: #e0f3db;
#   color: #000000;
# }
# #T_91909_row19_col2 {
#   background-color: #d7efd1;
#   color: #000000;
# }
# #T_91909_row19_col4 {
#   background-color: #f3fbed;
#   color: #000000;
# }
# #T_91909_row20_col1 {
#   background-color: #e1f3dc;
#   color: #000000;
# }
# #T_91909_row20_col2 {
#   background-color: #bde5be;
#   color: #000000;
# }
# #T_91909_row20_col5 {
#   background-color: #edf8e7;
#   color: #000000;
# }
# #T_91909_row21_col1, #T_91909_row32_col2, #T_91909_row38_col1 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_91909_row21_col2, #T_91909_row23_col2 {
#   background-color: #dcf1d6;
#   color: #000000;
# }
# #T_91909_row21_col3, #T_91909_row38_col3 {
#   background-color: #f4fbed;
#   color: #000000;
# }
# #T_91909_row21_col4 {
#   background-color: #b3e1ba;
#   color: #000000;
# }
# #T_91909_row22_col1 {
#   background-color: #e4f4de;
#   color: #000000;
# }
# #T_91909_row22_col2 {
#   background-color: #d5eece;
#   color: #000000;
# }
# #T_91909_row22_col4 {
#   background-color: #abdeb6;
#   color: #000000;
# }
# #T_91909_row23_col1 {
#   background-color: #e4f5df;
#   color: #000000;
# }
# #T_91909_row23_col4 {
#   background-color: #ccebc6;
#   color: #000000;
# }
# #T_91909_row24_col1, #T_91909_row39_col2 {
#   background-color: #e5f5e0;
#   color: #000000;
# }
# #T_91909_row24_col2, #T_91909_row26_col4 {
#   background-color: #cdebc6;
#   color: #000000;
# }
# #T_91909_row24_col4 {
#   background-color: #b2e1b9;
#   color: #000000;
# }
# #T_91909_row25_col1, #T_91909_row37_col3 {
#   background-color: #e6f5e0;
#   color: #000000;
# }
# #T_91909_row25_col4 {
#   background-color: #b4e2ba;
#   color: #000000;
# }
# #T_91909_row26_col1 {
#   background-color: #e9f6e3;
#   color: #000000;
# }
# #T_91909_row26_col2, #T_91909_row30_col4 {
#   background-color: #dbf1d5;
#   color: #000000;
# }
# #T_91909_row27_col4 {
#   background-color: #cbeac4;
#   color: #000000;
# }
# #T_91909_row28_col4 {
#   background-color: #c9eac4;
#   color: #000000;
# }
# #T_91909_row29_col2 {
#   background-color: #daf0d4;
#   color: #000000;
# }
# #T_91909_row29_col4 {
#   background-color: #d8f0d2;
#   color: #000000;
# }
# #T_91909_row30_col2, #T_91909_row34_col2 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_91909_row31_col1 {
#   background-color: #eff9e9;
#   color: #000000;
# }
# #T_91909_row31_col4, #T_91909_row32_col4 {
#   background-color: #ddf2d7;
#   color: #000000;
# }
# #T_91909_row32_col1 {
#   background-color: #f0f9e9;
#   color: #000000;
# }
# #T_91909_row33_col1, #T_91909_row34_col1, #T_91909_row35_col2 {
#   background-color: #f1f9ea;
#   color: #000000;
# }
# #T_91909_row35_col4, #T_91909_row37_col5, #T_91909_row39_col5 {
#   background-color: #e1f4dc;
#   color: #000000;
# }
# #T_91909_row36_col1 {
#   background-color: #afe0b8;
#   color: #000000;
# }
# #T_91909_row37_col4 {
#   background-color: #b5e2bb;
#   color: #000000;
# }
# #T_91909_row38_col2 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_91909_row39_col3 {
#   background-color: #f3faec;
#   color: #000000;
# }
# </style>
# <table id="T_9190

# %%
px.scatter(TOPICS.reset_index(), 'hobbes', 'rousseau', 
           hover_name='label', text='topic_id', 
           size=(TOPICS.hobbes * TOPICS.rousseau),
           color='author',
           width=1000, height=650)

# %%
px.scatter(TOPICS.reset_index(), 'hobbes', 'locke', 
           hover_name='label', text='topic_id', 
           size=(TOPICS.hobbes * TOPICS.locke),
           color='author',
           width=1000, height=650)

# %%
px.scatter(TOPICS.reset_index(), 'rousseau', 'locke', 
           hover_name='label', text='topic_id', 
           size=(TOPICS.rousseau * TOPICS.locke),
           color='author',
           width=1000, height=650)

# %% [markdown]
# ## Save tables

# %%
os.chdir('C:/Users/linna/Box/MSDS/DS5001/Final Project/Corpus/')

# %%
#DOCS.to_csv('LDA_DOCS-chaps.csv')
#TOPICS.to_csv('LDA_TOPICS-9.csv')
#THETA.to_csv('LDA_THETA-9.csv')
#PHI.to_csv('LDA_PHI-9.csv')
